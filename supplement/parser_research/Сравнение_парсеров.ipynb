# %%
! apt install python3.10-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools-whl
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 35 not upgraded.
# Need to get 2,473 kB of archives.
# After this operation, 2,884 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.4 [1,680 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.1 [788 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.3 [5,716 B]
# Fetched 2,473 kB in 1s (1,688 kB/s)
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.3_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.3) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3.10-venv (3.10.12-1~22.04.3) ...

# %%
! python -m venv env

# %%
! source env/bin/activate

# %%
! pip install deeppavlov
# Out:
# Collecting deeppavlov
#   Downloading deeppavlov-1.5.0-py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.4/489.4 kB 8.9 MB/s eta 0:00:00
# Collecting fastapi<=0.89.1,>=0.47.0 (from deeppavlov)
#   Downloading fastapi-0.89.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.8 MB/s eta 0:00:00
# Collecting filelock<3.10.0,>=3.0.0 (from deeppavlov)
#   Downloading filelock-3.9.1-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: nltk<3.10.0,>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (3.8.1)
# Collecting numpy<1.24 (from deeppavlov)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 47.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas<1.6.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (1.5.3)
# Requirement already satisfied: prometheus-client<=1.16.0,>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (0.20.0)
# Collecting pydantic<2 (from deeppavlov)
#   Downloading pydantic-1.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.3 MB/s eta 0:00:00
# Collecting pybind11==2.10.3 (from deeppavlov)
#   Downloading pybind11-2.10.3-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 kB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (2.31.0)
# Collecting scikit-learn<1.1.0,>=0.24 (from deeppavlov)
#   Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 42.5 MB/s eta 0:00:00
# Collecting tqdm<4.65.0,>=4.42.0 (from deeppavlov)
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.2 MB/s eta 0:00:00
# Collecting uvicorn<0.19.0,>=0.13.0 (from deeppavlov)
#   Downloading uvicorn-0.18.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (0.42.0)
# Collecting scipy==1.10.0 (from deeppavlov)
#   Downloading scipy-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 45.5 MB/s eta 0:00:00
# Collecting starlette==0.22.0 (from fastapi<=0.89.1,>=0.47.0->deeppavlov)
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (3.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (2023.12.25)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.0.0->deeppavlov) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.0.0->deeppavlov) (2023.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->deeppavlov) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.1.0,>=0.24->deeppavlov) (3.3.0)
# Collecting h11>=0.8 (from uvicorn<0.19.0,>=0.13.0->deeppavlov)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0,>=1.0.0->deeppavlov) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (1.2.0)
# Installing collected packages: tqdm, pydantic, pybind11, numpy, h11, filelock, uvicorn, starlette, scipy, scikit-learn, fastapi, deeppavlov
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.3
#     Uninstalling pydantic-2.6.3:
#       Successfully uninstalled pydantic-2.6.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.1
#     Uninstalling filelock-3.13.1:
#       Successfully uninstalled filelock-3.13.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# chex 0.1.85 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# Successfully installed deeppavlov-1.5.0 fastapi-0.89.1 filelock-3.9.1 h11-0.14.0 numpy-1.23.5 pybind11-2.10.3 pydantic-1.10.14 scikit-learn-1.0.2 scipy-1.10.0 starlette-0.22.0 tqdm-4.64.1 uvicorn-0.18.3

# %%
# !python -m deeppavlov install morpho_ru_syntagrus_bert
# Out:
# Collecting pytorch-crf==0.7.*
#   Downloading pytorch_crf-0.7.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2
# Collecting torch<1.14.0,>=1.6.0
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<1.14.0,>=1.6.0) (4.10.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<1.14.0,>=1.6.0)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 68.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<1.14.0,>=1.6.0)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<1.14.0,>=1.6.0)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<1.14.0,>=1.6.0)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14.0,>=1.6.0) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14.0,>=1.6.0) (0.42.0)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1
# Ignoring transformers: markers 'python_version < "3.8"' don't match your environment
# Collecting transformers==4.30.0
#   Downloading transformers-4.30.0-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (3.9.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 59.0 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (4.64.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (2024.2.2)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed tokenizers-0.13.3 transformers-4.30.0
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 36.5 MB/s eta 0:00:00
# Collecting spacy<3.6.0,>=3.5.0 (from en-core-web-sm==3.5.0)
#   Downloading spacy-3.5.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Collecting thinc<8.2.0,>=8.1.8 (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0)
#   Downloading thinc-8.1.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (919 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 919.6/919.6 kB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.0)
# Collecting pathy>=0.10.0 (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0)
#   Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0)
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.5)
# Installing collected packages: pathlib-abc, pathy, thinc, spacy, en-core-web-sm
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.3
#     Uninstalling thinc-8.2.3:
#       Successfully uninstalled thinc-8.2.3
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.4
#     Uninstalling spacy-3.7.4:
#       Successfully uninstalled spacy-3.7.4
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.7.1
#     Uninstalling en-core-web-sm-3.7.1:
#       Successfully uninstalled en-core-web-sm-3.7.1
# Successfully installed en-core-web-sm-3.5.0 pathlib-abc-0.1.1 pathy-0.11.0 spacy-3.5.4 thinc-8.1.12
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Collecting ru-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.5.0/ru_core_news_sm-3.5.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 47.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.5.0) (3.5.4)
# Collecting pymorphy3>=1.0.0 (from ru-core-news-sm==3.5.0)
#   Downloading pymorphy3-2.0.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.2 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1 (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 81.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.1.5)
# Installing collected packages: pymorphy3-dicts-ru, dawg-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 pymorphy3-2.0.1 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.5.0

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# 2024-03-11 15:02:32.747515: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-11 15:02:32.747577: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-11 15:02:32.748860: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-11 15:02:32.756763: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 15:02:34.988492: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-11 15:02:38.543167: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-11 15:02:38.544156: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-11 15:02:38.544407: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting ru-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.5.0/ru_core_news_sm-3.5.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.5.0) (3.5.4)
# Requirement already satisfied: pymorphy3>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.5.0) (2.0.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (2.4.417150.4580142)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
! pip install Natasha
# Out:
# Collecting Natasha
#   Downloading natasha-1.6.0-py3-none-any.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 29.6 MB/s eta 0:00:00
# Collecting pymorphy2 (from Natasha)
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 6.5 MB/s eta 0:00:00
# Collecting razdel>=0.5.0 (from Natasha)
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting navec>=0.9.0 (from Natasha)
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Collecting slovnet>=0.6.0 (from Natasha)
#   Downloading slovnet-0.6.0-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 6.9 MB/s eta 0:00:00
# Collecting yargy>=0.16.0 (from Natasha)
#   Downloading yargy-0.16.0-py3-none-any.whl (33 kB)
# Collecting ipymarkup>=0.8.0 (from Natasha)
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting intervaltree>=3 (from ipymarkup>=0.8.0->Natasha)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from navec>=0.9.0->Natasha) (1.23.5)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy2->Natasha) (0.7.2)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2->Natasha)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 106.7 MB/s eta 0:00:00
# Collecting docopt>=0.6 (from pymorphy2->Natasha)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from intervaltree>=3->ipymarkup>=0.8.0->Natasha) (2.4.0)
# Building wheels for collected packages: docopt, intervaltree
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=c0b1603f0a1cdc4c1954c6f4a2f63a612b715674ccd89e0aa1ec8bae1a726818
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26095 sha256=eb62fcee40baae82c335a890c5918521711124482b6edc4e9284fe26d3069af6
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
# Successfully built docopt intervaltree
# Installing collected packages: razdel, pymorphy2-dicts-ru, docopt, pymorphy2, navec, intervaltree, yargy, slovnet, ipymarkup, Natasha
# Successfully installed Natasha-1.6.0 docopt-0.6.2 intervaltree-3.1.0 ipymarkup-0.9.0 navec-0.10.0 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 razdel-0.5.0 slovnet-0.6.0 yargy-0.16.0

# %%
! pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.8.1-py3-none-any.whl (970 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.4/970.4 kB 10.6 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.23.5)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.2.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.64.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.10.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.3.0->stanza) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.3.0->stanza) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.2.2)
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.10.1 stanza-1.8.1

# %%
! pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.4)
# Collecting spacy
#   Downloading spacy-3.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (922 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.3/922.3 kB 39.3 MB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.12
#     Uninstalling thinc-8.1.12:
#       Successfully uninstalled thinc-8.1.12
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.4
#     Uninstalling spacy-3.5.4:
#       Successfully uninstalled spacy-3.5.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.5.0 requires spacy<3.6.0,>=3.5.0, but you have spacy 3.7.4 which is incompatible.
# ru-core-news-sm 3.5.0 requires spacy<3.6.0,>=3.5.0, but you have spacy 3.7.4 which is incompatible.
# Successfully installed spacy-3.7.4 thinc-8.2.3

# %% [markdown]
# # Сравнение теггеров

# %%
import json
import pandas as pd
from sklearn.metrics import accuracy_score
from nltk import word_tokenize
import nltk
nltk.download('punkt')
from string import punctuation
punctuation += '—'+'–'

import stanza
stanza.download('ru')

stnz = stanza.Pipeline('ru', use_gpu = True)
stnz_cpu = stanza.Pipeline('ru', use_gpu = False)

import spacy
spacy.prefer_gpu()
spc = spacy.load("ru_core_news_sm")

from natasha import (
    Segmenter,
    MorphVocab,
    NewsEmbedding,
    NewsMorphTagger,
    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)

from pymystem3 import Mystem

m = Mystem()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: ru (Russian) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/default.zip:   0%|          | 0…
# INFO:stanza:Downloaded file to /root/stanza_resources/ru/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# | ner       | wikiner            |
# ==================================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# | ner       | wikiner            |
# ==================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:910: UserWarning: [W095] Model 'ru_core_news_sm' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.7.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Installing mystem to /root/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.1-linux-64bit.tar.gz

# %%
from deeppavlov import build_model

dp = build_model("morpho_ru_syntagrus_bert", download=True, install=True)
# Out:
# 2024-03-11 15:57:02.455 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/deeppavlov_data/morpho_tagger/UD2.3/ru_syntagrus.tar.gz to /root/.deeppavlov/downloads/UD2.3_source/ru_syntagrus.tar.gz
# INFO:deeppavlov.core.data.utils:Downloading from http://files.deeppavlov.ai/deeppavlov_data/morpho_tagger/UD2.3/ru_syntagrus.tar.gz to /root/.deeppavlov/downloads/UD2.3_source/ru_syntagrus.tar.gz
# 100%|██████████| 16.7M/16.7M [00:01<00:00, 9.27MB/s]
# 2024-03-11 15:57:05.284 INFO in 'deeppavlov.core.data.utils'['utils'] at line 276: Extracting /root/.deeppavlov/downloads/UD2.3_source/ru_syntagrus.tar.gz archive into /root/.deeppavlov/downloads/UD2.3_source/ru_syntagrus
# INFO:deeppavlov.core.data.utils:Extracting /root/.deeppavlov/downloads/UD2.3_source/ru_syntagrus.tar.gz archive into /root/.deeppavlov/downloads/UD2.3_source/ru_syntagrus
# 2024-03-11 15:57:06.868 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/deeppavlov_data/syntax_parsing/morpho_ru_syntagrus_torch_bert.tar.gz to /root/.deeppavlov/models/morpho_ru_syntagrus_torch_bert.tar.gz
# INFO:deeppavlov.core.data.utils:Downloading from http://files.deeppavlov.ai/deeppavlov_data/syntax_parsing/morpho_ru_syntagrus_torch_bert.tar.gz to /root/.deeppavlov/models/morpho_ru_syntagrus_torch_bert.tar.gz
# 100%|██████████| 1.63G/1.63G [01:28<00:00, 18.5MB/s]
# 2024-03-11 15:58:35.976 INFO in 'deeppavlov.core.data.utils'['utils'] at line 276: Extracting /root/.deeppavlov/models/morpho_ru_syntagrus_torch_bert.tar.gz archive into /root/.deeppavlov/models/morpho_ru_syntagrus_torch_bert
# INFO:deeppavlov.core.data.utils:Extracting /root/.deeppavlov/models/morpho_ru_syntagrus_torch_bert.tar.gz archive into /root/.deeppavlov/models/morpho_ru_syntagrus_torch_bert
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:910: UserWarning: [W095] Model 'ru_core_news_sm' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.7.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %% [markdown]
# ### Проблемы автоматической разметки:
# Рассмотрим случаи, которые вызвают трудности при автоматической разработке. В корпусе будут представлены по 1-2 предложения на каждый пример.
# - омонимия разного рода:
#     - существительное vs глагол *печь, ели*
#     - причастия vs прилагательные *вареный, рассенный*
#     - наречия vs предлоги: *вблизи*
# - слова с дефисами.
#     - Не хотим делить:
#          - предлоги: *из-за*
#          - наречия: *по-настоящему*
#          - названия городов, в том числе другие части речи, образованные от их названий: *Нью-Йорк*, *Йошкар-Олинский*
#      - Хотим делить:
#          - частицы: *-таки*
#          - маршрут: *Белорецк-Магнитогорск*
#          - диапазон:*5-6*
# - имена собственные, как экзотические, так и фамилии на *-ов, -их*: *Тарасевича (Тарасевич), Петровский, Лидваль, Шемякин, Резвых, от Гомера до Андре Жида*
# - сокращения *тыс., ред.*
#
# * Категория "*Редкие слова*" по [Ляшевская et.al 2010]:
#     * слова с неизвестным словарю корнем, но образованные с помощью продуктивных аффиксов. В моем корпусе: *симпим (симпить), заспавнилась, коупила (коупить), инфодамплю, галюники, панчи, ремув, на самике (самик), фички*
#     * совсем непонятные слова. В моем корпусе: *на бэбича (бэбич), упртст, делюлю (прилагательное)*
#     * окказиональные формы: *стригя, пья, победу, льзя*
#     * аббривеатуры: *МГУ, ВМО, РФФИ, РАН*
#
# * случайно взятые слова из тех, которые не сомгли распарсить в ГИКРЯ:
#   * *Егошная, егошнее* - просторечия
#   * *Егэшный, ВААЩе* - неологизмы и слэнг,
#   * *пяЦот, пэсню* - подражание устной речи
#   * *пюдям, пюока* - опечатки
#
#
# От себя:
# * *всеееееее* - удвоенные буквы
# * другое: *покашт, ниче, ченить*

# %% [markdown]
# ## Словарь универсальных тегов
# В рассмотрении будут **Natasha, Stanza, Mystem, Spacy, DeepPavlov**
#
# Natasha, Stanza и Spacy используют Upos, у Mystem свои теги. Сравним, как это будет работать для разных частей речи и подберем один враиант

# %% [markdown]
# | часть речи | тег Mystem | Upos | Наш итог |
# |:----------:|:----------:|:---------:|:--------:|
# | прилагательное | A | ADJ | **ADJ** |
# | наречие | ADV | ADV | **ADV** |
# | местоименное наречие | ADVPRO | ADV | **ADV** |
# | числительное-прилагательное | ANUM | ADJ | **ADJ** |
# | местоимение-прилагательное | APRO | DET | **DET** |
# | часть композита - сложного слова | COM | ? | **NOUN** |
# | сочинительный союз | CONJ | CCONJ | **CONJ** |
# | подчинительный союз | CONJ | SCONJ | **CONJ** |
# | междометие | INTJ | INTJ | **INTJ** |
# | числительное | NUM | NUM | **NUM** |
# | частица | PART | PART | **PART** |
# | предлог| PR | ADP | **ADP** |
# | существительное| S | NOUN | **NOUN** |
# | местоимение-существительное| SPRO | PRON | **PRON** |
# | глагол | V | VERB | **VERB** |
# | вспомогательный глагол | V | AUX | **VERB**
# | имя собственное | S | PROPN | **NOUN** |
# | пунктуация | - | PUNCT | **NA** |
# | символ | - | SYM | **NA** |
#
#
#
# Итог: в основном теги в Stanza и Natasha останутся нетронутыми. Имена собственные вспомогательные глаголы и союзы будут более обощены, а символы и пункутуация вовсе не будут учитываться.

# %%
tokens_frame = pd.DataFrame(columns = ['Токен', 'Тег_1', 'Тег_2']) # второй тег для неоднозначных по моему мнению случаев

# %% [markdown]
# Использую токенизацию с помощью nltk для удобства и превращаю корпус в таблицу. Далее надо разметить вручную все токены, проверить правильность токенизации

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/писько/Сравнение парсеров/corpora.txt', 'r', encoding ='utf-8') as file:
    raw_text = file.read()
    tokens_text = word_tokenize(raw_text)
    tokens_frame['Токен'] = tokens_text

# %%
#tokens_frame.to_csv('/content/drive/My Drive/pisko/empty_tokens.csv')

# %%
# подгружаю размеченные вручную токены
gold_taggs = pd.read_csv('/content/drive/My Drive/писько/Сравнение парсеров/tagged_lemmas.csv')

# %%
gold_taggs
# Out:
#        Токен Тег_1 Тег_2    лемма лемма 2
# 0    ﻿Входим  VERB   NaN    войти     NaN
# 1          в   ADP   NaN        в     NaN
# 2        дом  NOUN   NaN      дом     NaN
# 3          ,   NaN   NaN        ,     NaN
# 4     открыв  VERB   NaN  открыть     NaN
# ..       ...   ...   ...      ...     ...
# 666    пюока  PART   NaN     пока     NaN
# 667        ,   NaN   NaN        ,     NaN
# 668       до   ADP   NaN       до     NaN
# 669  скорова   ADJ   NaN   скорый     NaN
# 670        !   NaN   NaN        !     NaN
#
# [671 rows x 5 columns]

# %%
print('Размер корпуса: ', len(gold_taggs))
# Out:
# Размер корпуса:  671

# %% [markdown]
# ## Задаем функции

# %%
upos_tags = {'CCONJ': 'CONJ',
             'SCONJ': 'CONJ',
             'AUX': 'VERB',
             'PROPN': 'NOUN',
             'PUNCT': '',
             'SYM': ''
}

# %%
mystem_tags = {'A': 'ADJ',
               'ADVPRO': 'ADV',
               'ANUM': 'ADJ',
               'APRO': 'DET',
               'COM': 'NOUN',
               'PR': 'ADP',
               'S': 'NOUN',
               'SPRO': 'PRON',
               'V': 'VERB',
              }

# %%
def compare_right_tokens(token, tag, lemma, gold, results_tag, results_lemma, gold_tags, gold_lemmas, index):
    tag_gold_1 = gold['Тег_1'][index]
    tag_gold_2 = gold['Тег_2'][index]
    lemma_gold_1 = str(gold['лемма'][index]).lower()
    lemma_gold_2 = str(gold['лемма 2'][index]).lower()

    if tag == tag_gold_2:
         gold_tags.append(tag_gold_2)
    else: gold_tags.append(tag_gold_1)

    if lemma.lower() == lemma_gold_2.lower():
         gold_lemmas.append(lemma_gold_2)
    else: gold_lemmas.append(lemma_gold_1)
    results_tag.append(tag)
    results_lemma.append(lemma.lower())

# %%
def compare(gold, unified_parser):
    results_tag = []  # сюда будем писать результаты
    results_lemma = []
    gold_tags = []     # сюда будем писать мои теги
    gold_lemmas = []
    index = 0
    for token, tag, lemma in zip(unified_parser['Токен'], unified_parser['Тег'], unified_parser['Лемма']):
        token_gold = gold['Токен'][index]
        tag_gold_1 = gold['Тег_1'][index]
        lemma_gold_1 = str(gold['лемма'][index]).lower()

        # если все нормально с токинизацией
        if token == token_gold:
            res = compare_right_tokens(token, tag, lemma, gold, results_tag, results_lemma, gold_tags, gold_lemmas, index)
            index += 1

        # если неправильная токенизация
        else:
            if token in str(token_gold): # парсер побил на токены лишний раз
                print('Парсер перебил ' + str(token_gold) + '. Выдал: ' + str(token))

                if token_gold.endswith(token):
                    results_tag.append('')
                    results_lemma.append('')
                    gold_tags.append(tag_gold_1)
                    gold_lemmas.append(lemma_gold_1)
                    index += 1
                else: continue # без прибавления счетчика, пока не дойдем до конца токена

            elif str(token_gold) in token: # парсер недобил
                print('Парсер недобил ' + str(token_gold) + '. Выдал: ' + str(token))
                while not token.endswith(token_gold):
                    token_gold = gold['Токен'][index]
                    lemma_gold = gold['лемма'][index]
                    index += 1
                results_tag.append('')
                results_lemma.append('')
                gold_lemmas.append(str(gold['лемма'][index]).lower())
                gold_tags.append(gold['Тег_1'][index])

            else:
                print('Не совпадают:', token_gold, token)

    print('Точность по тегам:')
    print(accuracy_score(results_tag, gold_tags))
    print('Точность по леммам:')
    print(accuracy_score(results_lemma, gold_lemmas))

# %%
# создаем таблицу с разметкой теггера
def create_tagged_frame(tag_dict):
    new_frame = pd.DataFrame(columns = ['Токен', 'Тег', 'Лемма'], index = range(0, len(tag_dict)))
    tokens = [token[0] for token in tag_dict]
    tags = [tag[1] for tag in tag_dict]
    lemmas = [lemma[2] for lemma in tag_dict]

    new_frame['Токен'] = tokens
    new_frame['Тег'] = tags
    new_frame['Лемма'] = lemmas

    return new_frame

# %%
def unification(dct):
    unified = []
    for token_n_tag in dct:
        token = token_n_tag[0]
        tag = token_n_tag[1]
        lemma = token_n_tag[2]
        if tag in mystem_tags:
            unified.append((token, mystem_tags[tag], lemma))
        elif tag in upos_tags:
            unified.append((token, upos_tags[tag], lemma))
        else: unified.append((token, tag, lemma))
    return create_tagged_frame(unified)

# %% [markdown]
# # Stanza

# %%
# %%time
stanza_dict = [] # на самом деле не словарь, а лист коретежей, чтобы значения могли повторяться
analys = stnz_cpu(raw_text).to_dict()
for i in range(0, len(analys)):
    for sent in analys[i]:
        stanza_dict.append((sent['text'], sent['upos']))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/stanza/pipeline/core.py in __call__(self, doc, processors)
#     475
#     476     def __call__(self, doc, processors=None):
# --> 477         return self.process(doc, processors)
#     478
#     479 def main():
#
# /usr/local/lib/python3.10/dist-packages/stanza/pipeline/core.py in process(self, doc, processors)
#     426             if self.processors.get(processor_name):
#     427                 process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 428                 doc = process(doc)
#     429         return doc
#     430
#
# /usr/local/lib/python3.10/dist-packages/stanza/pipeline/ner_processor.py in process(self, document)
#     112                 preds = []
#     113                 for i, b in enumerate(batch):
# --> 114                     preds += trainer.predict(b)
#     115                 all_preds.append(preds)
#     116         # for each sentence, gather a list of predictions
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/ner/trainer.py in predict(self, batch, unsort)
#     142         self.model.eval()
#     143         #batch_size = word.size(0)
# --> 144         _, logits, trans = self.model(word, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#     145
#     146         # decode
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/ner/model.py in forward(self, sentences, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#     224                 char_reps_forward = self.charmodel_forward.get_representation(chars[0], charoffsets[0], charlens, char_orig_idx)
#     225                 char_reps_forward = PackedSequence(char_reps_forward.data, char_reps_forward.batch_sizes)
# --> 226                 char_reps_backward = self.charmodel_backward.get_representation(chars[1], charoffsets[1], charlens, char_orig_idx)
#     227                 char_reps_backward = PackedSequence(char_reps_backward.data, char_reps_backward.batch_sizes)
#     228                 inputs += [char_reps_forward, char_reps_backward]
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/common/char_model.py in get_representation(self, chars, charoffsets, charlens, char_orig_idx)
#     158     def get_representation(self, chars, charoffsets, charlens, char_orig_idx):
#     159         with torch.no_grad():
# --> 160             output, _, _ = self.forward(chars, charlens)
#     161             res = [output[i, offsets] for i, offsets in enumerate(charoffsets)]
#     162             res = unsort(res, char_orig_idx)
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/common/char_model.py in forward(self, chars, charlens, hidden)
#     151             hidden = (self.charlstm_h_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous(),
#     152                       self.charlstm_c_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous())
# --> 153         output, hidden = self.charlstm(embs, charlens, hx=hidden)
#     154         output = self.dropout(pad_packed_sequence(output, batch_first=True)[0])
#     155         decoded = self.decoder(output)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/common/packed_lstm.py in forward(self, input, lengths, hx)
#      20             input = pack_padded_sequence(input, lengths, batch_first=self.batch_first)
#      21
# ---> 22         res = self.lstm(input, hx)
#      23         if self.pad:
#      24             res = (pad_packed_sequence(res[0], batch_first=self.batch_first)[0], res[1])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     775                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     776         else:
# --> 777             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     778                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     779         output = result[0]
#
# KeyboardInterrupt:

# %%
# %%time
stanza_dict = [] # на самом деле не словарь, а лист коретежей, чтобы значения могли повторяться
analys = а.to_dict()
for i in range(0, len(analys)):
    for sent in analys[i]:
        if sent['lemma']:
          lemma = sent['lemma']
        else: lemma = None
        stanza_dict.append((sent['text'], sent['upos'], lemma))
# Out:
# CPU times: user 1.14 s, sys: 87.3 ms, total: 1.22 s
# Wall time: 1.22 s

# %%
stanza_dict[:10]
# Out:
# [('\ufeffВходим', 'VERB', 'свходить'),
#  ('в', 'ADP', 'в'),
#  ('дом', 'NOUN', 'дом'),
#  (',', 'PUNCT', ','),
#  ('открыв', 'VERB', 'открыть'),
#  ('дверь', 'NOUN', 'дверь'),
#  (',', 'PUNCT', ','),
#  ('попадаем', 'VERB', 'попадать'),
#  ('в', 'ADP', 'в'),
#  ('кухню', 'NOUN', 'кухня')]

# %%
stanza_frame = unification(stanza_dict)

# %%
stanza_frame
# Out:
#        Токен   Тег     Лемма
# 0    ﻿Входим  VERB  свходить
# 1          в   ADP         в
# 2        дом  NOUN       дом
# 3          ,               ,
# 4     открыв  VERB   открыть
# ..       ...   ...       ...
# 659    пюока  VERB   пюокать
# 660        ,               ,
# 661       до   ADP        до
# 662  скорова  NOUN   скорова
# 663        !               !
#
# [664 rows x 3 columns]

# %%
results_lemma, gold_lemmas = compare(gold_taggs, stanza_frame)
# Out:
# Парсер недобил Немцы. Выдал: Немцы-таки
# Парсер недобил Белорецк. Выдал: Белорецк-Магнитогорск
# Парсер недобил тыс. Выдал: тыс.
# Парсер недобил Прим. Выдал: Прим.
# Парсер недобил ред. Выдал: ред.
# Точность по тегам:
# 0.7469879518072289
# Точность по леммам:
# 0.9081325301204819

# %% [markdown]
# # Natasha

# %%
# %%time
natasha_dict = [] # на самом деле не слвоарь, а лист коретежей, чтобы значения могли повторяться
doc = Doc(raw_text)
doc.segment(segmenter)
doc.tag_morph(morph_tagger)

for token in doc.tokens:
    token.lemmatize(morph_vocab)
    natasha_dict.append((token.text, token.pos, token.lemma))
# Out:
# CPU times: user 111 ms, sys: 53.2 ms, total: 164 ms
# Wall time: 92.5 ms

# %%
natasha_dict[:10]
# Out:
# [('\ufeffВходим', 'PUNCT', '\ufeffвходим'),
#  ('в', 'ADP', 'в'),
#  ('дом', 'NOUN', 'дом'),
#  (',', 'PUNCT', ','),
#  ('открыв', 'VERB', 'открыть'),
#  ('дверь', 'NOUN', 'дверь'),
#  (',', 'PUNCT', ','),
#  ('попадаем', 'VERB', 'попадать'),
#  ('в', 'ADP', 'в'),
#  ('кухню', 'NOUN', 'кухня')]

# %%
natasha_frame = unification(natasha_dict)

# %%
natasha_frame.head()
# Out:
#      Токен   Тег    Лемма
# 0  ﻿Входим        ﻿входим
# 1        в   ADP        в
# 2      дом  NOUN      дом
# 3        ,              ,
# 4   открыв  VERB  открыть

# %%
compare(gold_taggs, natasha_frame)
# Out:
# Парсер недобил 5. Выдал: 5-6
# Парсер недобил Немцы. Выдал: Немцы-таки
# Парсер перебил А.. Выдал: А
# Парсер перебил А.. Выдал: .
# Парсер перебил Е.. Выдал: Е
# Парсер перебил Е.. Выдал: .
# Парсер недобил Белорецк. Выдал: Белорецк-Магнитогорск
# Парсер недобил 2001. Выдал: 2001-2002
# Точность по тегам:
# 0.7375565610859729
# Точность по леммам:
# 0.9140271493212669

# %% [markdown]
# # Mystem

# %%
# %%time
doc = m.analyze(raw_text)
# Out:
# CPU times: user 5.42 ms, sys: 2.24 ms, total: 7.65 ms
# Wall time: 54.9 ms

# %% [markdown]
# Заметим, что работает в разы дольше соперниц

# %%
doc[1]['analysis'][0]['lex']
# Out:
# 'входить'

# %%
mystem_dict = [] # на самом деле не слвоарь, а лист коретежей, чтобы значения могли повторяться
for i in range(0, len(doc)):
    txt = doc[i]['text'].replace(' ', '') #приклеивает пробелы к пунктуации
    try:
        mystem_dict.append((txt,
                            doc[i]['analysis'][0]['gr'].split('=')[0].split(',')[0],
                           doc[i]['analysis'][0]['lex']))
    except Exception as e:
        #print(e)
        if txt.isalpha() or txt.isdigit(): #пропускает незнакомые слова, числа и пунктуацию, что плохо
            mystem_dict.append((txt, ' ', ' '))
        else:
            if (txt in punctuation or txt[0] in punctuation) and txt != '':
                mystem_dict.append((txt, ' ', ' '))

# %%
mystem_dict[:10]
# Out:
# [('Входим', 'V', 'входить'),
#  ('в', 'PR', 'в'),
#  ('дом', 'S', 'дом'),
#  (',', ' ', ' '),
#  ('открыв', 'V', 'открывать'),
#  ('дверь', 'S', 'дверь'),
#  (',', ' ', ' '),
#  ('попадаем', 'V', 'попадать'),
#  ('в', 'PR', 'в'),
#  ('кухню', 'S', 'кухня')]

# %%
mystem_frame = unification(mystem_dict)

# %%
compare(gold_taggs, mystem_frame)
# Out:
# Парсер перебил ﻿Входим. Выдал: Входим
# Парсер перебил А.. Выдал: А
# Парсер перебил А.. Выдал: .
# Парсер перебил Е.. Выдал: Е
# Парсер перебил Е.. Выдал: .
# Парсер перебил 15,5. Выдал: 15
# Парсер перебил 15,5. Выдал: ,
# Парсер перебил 15,5. Выдал: 5
# Парсер недобил .. Выдал: .):
# Точность по тегам:
# 0.7339312406576981
# Точность по леммам:
# 0.7085201793721974

# %% [markdown]
# # Spacy

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install -U 'spacy[cuda11]'
# Out:
# Requirement already satisfied: spacy[cuda11] in /usr/local/lib/python3.10/dist-packages (3.7.4)
# WARNING: spacy 3.7.4 does not provide the extra 'cuda11'
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy[cuda11]) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[cuda11]) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda11]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda11]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda11]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda11]) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy[cuda11]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy[cuda11]) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy[cuda11]) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy[cuda11]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy[cuda11]) (2.1.5)

# %%
# %%time
spc_dict = [] # на самом деле не слвоарь, а лист коретежей, чтобы значения могли повторяться
doc = spc(raw_text)
for token in doc:
  if token.text != '\n':
    spc_dict.append((token.text, token.pos_, token.lemma_))
# Out:
# CPU times: user 254 ms, sys: 0 ns, total: 254 ms
# Wall time: 255 ms

# %%
spc_dict[:10]
# Out:
# [('\ufeffВходим', 'PROPN', '\ufeffвходим'),
#  ('в', 'ADP', 'в'),
#  ('дом', 'NOUN', 'дом'),
#  (',', 'PUNCT', ','),
#  ('открыв', 'VERB', 'открыть'),
#  ('дверь', 'NOUN', 'дверь'),
#  (',', 'PUNCT', ','),
#  ('попадаем', 'VERB', 'попадать'),
#  ('в', 'ADP', 'в'),
#  ('кухню', 'NOUN', 'кухня')]

# %%
spc_frame = unification(spc_dict)

# %%
compare(gold_taggs, spc_frame)
# Out:
# Парсер перебил из-за. Выдал: из
# Парсер перебил из-за. Выдал: -
# Парсер перебил из-за. Выдал: за
# Парсер перебил из-за. Выдал: из
# Парсер перебил из-за. Выдал: -
# Парсер перебил из-за. Выдал: за
# Парсер перебил по-настоящему. Выдал: по
# Парсер перебил по-настоящему. Выдал: -
# Парсер перебил по-настоящему. Выдал: настоящему
# Парсер перебил Йошкар-Олинском. Выдал: Йошкар
# Парсер перебил Йошкар-Олинском. Выдал: -
# Парсер перебил Йошкар-Олинском. Выдал: Олинском
# Парсер перебил Нью-Йорке. Выдал: Нью
# Парсер перебил Нью-Йорке. Выдал: -
# Парсер перебил Нью-Йорке. Выдал: Йорке
# Парсер перебил какой-то. Выдал: какой
# Парсер перебил какой-то. Выдал: -
# Парсер перебил какой-то. Выдал: то
# Не совпадают: Заболел
# Парсер недобил тыс. Выдал: тыс.
# Парсер недобил ). Выдал: ):
# Парсер перебил когда-нибудь. Выдал: когда
# Парсер перебил когда-нибудь. Выдал: -
# Парсер перебил когда-нибудь. Выдал: нибудь
# Точность по тегам:
# 0.7369207772795217
# Точность по леммам:
# 0.852017937219731

# %% [markdown]
# # DeepPavlov

# %%
! pip install conllu
# Out:
# Collecting conllu
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.3

# %%
 from conllu import parse

# %%
# %%time
dp_doc = dp(raw_text.split('\n')) #не может сам бить
# Out:
# CPU times: user 4.43 s, sys: 4.76 ms, total: 4.44 s
# Wall time: 5.63 s

# %%
dp_doc[:3]
# Out:
# ['1\t\ufeffВходим\t\ufeffВходим\tVERB\t_\tAspect=Imp|Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n2\tв\tв\tADP\t_\t_\t_\t_\t_\t_\n3\tдом\tдом\tNOUN\t_\tAnimacy=Inan|Case=Acc|Gender=Masc|Number=Sing\t_\t_\t_\t_\n4\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n5\tоткрыв\tоткрыть\tVERB\t_\tAspect=Perf|Tense=Past|VerbForm=Conv|Voice=Act\t_\t_\t_\t_\n6\tдверь\tдверь\tNOUN\t_\tAnimacy=Inan|Case=Acc|Gender=Fem|Number=Sing\t_\t_\t_\t_\n7\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n8\tпопадаем\tпопадать\tVERB\t_\tAspect=Imp|Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n9\tв\tв\tADP\t_\t_\t_\t_\t_\t_\n10\tкухню\tкухня\tNOUN\t_\tAnimacy=Inan|Case=Acc|Gender=Fem|Number=Sing\t_\t_\t_\t_\n11\t:\t:\tPUNCT\t_\t_\t_\t_\t_\t_\n12\tпечь\tпечь\tNOUN\t_\tAnimacy=Inan|Case=Nom|Gender=Fem|Number=Sing\t_\t_\t_\t_\n13\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n14\tналево\tналево\tADV\t_\tDegree=Pos\t_\t_\t_\t_\n15\tокно\tокно\tNOUN\t_\tAnimacy=Inan|Case=Nom|Gender=Neut|Number=Sing\t_\t_\t_\t_\n16\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n17\tрядом\tрядом\tADV\t_\tDegree=Pos\t_\t_\t_\t_\n18\tнебольшой\tнебольшой\tADJ\t_\tCase=Nom|Degree=Pos|Gender=Masc|Number=Sing\t_\t_\t_\t_\n19\tстол\tстол\tNOUN\t_\tAnimacy=Inan|Case=Nom|Gender=Masc|Number=Sing\t_\t_\t_\t_\n20\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n21\tкеросиновая\tкеросиновый\tADJ\t_\tCase=Nom|Degree=Pos|Gender=Fem|Number=Sing\t_\t_\t_\t_\n22\tлампа\tлампа\tNOUN\t_\tAnimacy=Inan|Case=Nom|Gender=Fem|Number=Sing\t_\t_\t_\t_\n23\tи\tи\tCCONJ\t_\t_\t_\t_\t_\t_\n24\tтри\tтри\tNUM\t_\tCase=Nom\t_\t_\t_\t_\n25\tдеревянных\tдеревянных\tADJ\t_\tCase=Gen|Degree=Pos|Number=Plur\t_\t_\t_\t_\n26\tстула\tстул\tNOUN\t_\tAnimacy=Inan|Case=Gen|Gender=Masc|Number=Sing\t_\t_\t_\t_\n27\t.\t.\tPUNCT\t_\t_\t_\t_\t_\t_\n',
#  '1\tУшла\tуйти\tVERB\t_\tAspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n2\tона\tона\tPRON\t_\tCase=Nom|Gender=Fem|Number=Sing|Person=3\t_\t_\t_\t_\n3\tв\tв\tADP\t_\t_\t_\t_\t_\t_\n4\tсвою\tсвой\tDET\t_\tCase=Acc|Gender=Fem|Number=Sing\t_\t_\t_\t_\n5\tкомнату\tкомната\tNOUN\t_\tAnimacy=Inan|Case=Acc|Gender=Fem|Number=Sing\t_\t_\t_\t_\n6\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n7\tа\tа\tCCONJ\t_\t_\t_\t_\t_\t_\n8\tменя\tменя\tPRON\t_\tCase=Acc|Number=Sing|Person=1\t_\t_\t_\t_\n9\tсоседка\tсоседка\tNOUN\t_\tAnimacy=Anim|Case=Nom|Gender=Fem|Number=Sing\t_\t_\t_\t_\n10\t(\t(\tPUNCT\t_\t_\t_\t_\t_\t_\n11\tмилейшая\tмилейшая\tADJ\t_\tCase=Nom|Degree=Sup|Gender=Fem|Number=Sing\t_\t_\t_\t_\n12\tженщина\tженщина\tNOUN\t_\tAnimacy=Anim|Case=Nom|Gender=Fem|Number=Sing\t_\t_\t_\t_\n13\t)\t)\tPUNCT\t_\t_\t_\t_\t_\t_\n14\tпригласила\tпригласить\tVERB\t_\tAspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n15\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n16\tнаучила\tнаучить\tVERB\t_\tAspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n17\tнемецкий\tнемецкий\tADJ\t_\tAnimacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing\t_\t_\t_\t_\n18\tсливовый\tсливовый\tADJ\t_\tAnimacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing\t_\t_\t_\t_\n19\tпирог\tпирог\tNOUN\t_\tAnimacy=Inan|Case=Acc|Gender=Masc|Number=Sing\t_\t_\t_\t_\n20\tпечь\tпечь\tVERB\t_\tAspect=Imp|VerbForm=Inf|Voice=Act\t_\t_\t_\t_\n21\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n22\tуспокоила\tуспокоить\tVERB\t_\tAspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n23\tменя\tменя\tPRON\t_\tCase=Acc|Number=Sing|Person=1\t_\t_\t_\t_\n24\t(\t(\tPUNCT\t_\t_\t_\t_\t_\t_\n25\tу\tу\tADP\t_\t_\t_\t_\t_\t_\n26\tнее\tнее\tPRON\t_\tCase=Gen|Gender=Fem|Number=Sing|Person=3\t_\t_\t_\t_\n27\tдети\tребёнок\tNOUN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Plur\t_\t_\t_\t_\n28\tв\tв\tADP\t_\t_\t_\t_\t_\t_\n29\tмоем\tмой\tDET\t_\tCase=Loc|Gender=Masc|Number=Sing\t_\t_\t_\t_\n30\tвозрасте\tвозраст\tNOUN\t_\tAnimacy=Inan|Case=Loc|Gender=Masc|Number=Sing\t_\t_\t_\t_\n31\t)\t)\tPUNCT\t_\t_\t_\t_\t_\t_\n32\t.\t.\tPUNCT\t_\t_\t_\t_\t_\t_\n',
#  '1\tСидели\tсидеть\tVERB\t_\tAspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n2\tмы\tмы\tPRON\t_\tCase=Nom|Number=Plur|Person=1\t_\t_\t_\t_\n3\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n4\tзначит\tзначить\tADV\t_\tDegree=Pos\t_\t_\t_\t_\n5\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n6\tс\tс\tADP\t_\t_\t_\t_\t_\t_\n7\tним\tним\tPRON\t_\tCase=Ins|Gender=Masc|Number=Sing|Person=3\t_\t_\t_\t_\n8\tв\tв\tADP\t_\t_\t_\t_\t_\t_\n9\tкафе\tкафе\tNOUN\t_\tAnimacy=Inan|Case=Loc|Gender=Neut|Number=Sing\t_\t_\t_\t_\n10\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n11\tели\tесть\tVERB\t_\tAspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n12\t,\t,\tPUNCT\t_\t_\t_\t_\t_\t_\n13\tпили\tпить\tVERB\t_\tAspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act\t_\t_\t_\t_\n14\t.\t.\tPUNCT\t_\t_\t_\t_\t_\t_\n']

# %%
dp_dict = [] # на самом деле не слвоарь, а лист коретежей, чтобы значения могли повторяться
for line in dp_doc:
  for token in parse(line)[0]:
    dp_dict.append((token['form'], token['upos'], token['lemma']))

# %%
dp_dict[:10]
# Out:
# [('\ufeffВходим', 'VERB', '\ufeffВходим'),
#  ('в', 'ADP', 'в'),
#  ('дом', 'NOUN', 'дом'),
#  (',', 'PUNCT', ','),
#  ('открыв', 'VERB', 'открыть'),
#  ('дверь', 'NOUN', 'дверь'),
#  (',', 'PUNCT', ','),
#  ('попадаем', 'VERB', 'попадать'),
#  ('в', 'ADP', 'в'),
#  ('кухню', 'NOUN', 'кухня')]

# %%
dp_frame = unification(dp_dict)

# %%
compare(gold_taggs, dp_frame)
# Out:
# Парсер недобил 5. Выдал: 5-6
# Парсер недобил Немцы. Выдал: Немцы-таки
# Парсер недобил Белорецк. Выдал: Белорецк-Магнитогорск
# Парсер недобил 2001. Выдал: 2001-2002
# Точность по тегам:
# 0.7541478129713424
# Точность по леммам:
# 0.8235294117647058

# %% [markdown]
# ### Итог
#
# || Stanza | Natasha | MyStem | Spacy | DeepPavlov |
# |:----------:|:----------:|:----------:|:---------:|:--------:|:--------:|
# |точность тег|0.745 | 0.736 | 0.732 | 0.735 | 0.752 |
# |точность лемма|0.908 | 0.914 | 0.708 | 0.85| 0.823 |
# |время CPU|17.5 s|136 ms|1.13 s| 615 ms|11.6 s|
# |время GPU|1.22 s|92.5 ms|54.9 ms| 255 ms|4 s|

# %% [markdown]
# Хотя DeepPavlov самый точный, он работает слишком долго.
# Самый быстрый парсер - Natasha, по точности превосходит MyStem и Spacy
